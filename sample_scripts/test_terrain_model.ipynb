# %%
import os

from matplotlib import pyplot
import matplotlib.cm as cm
from occpy import TerrainModel
import numpy as np

# %%
dtm_file = "/home/wcherlet/repos/OccPy/data/DSM_FP05_swissSurface3D_10cm.tif"
model = TerrainModel.TerrainModel(dtm_file)

dtm = model.dtm.read(1)

flipped = np.flipud(dtm)


pyplot.imshow(model.dtm.read(1), cmap=cm.gray)

pyplot.imshow(flipped, cmap=cm.gray)

# %%
print(model.get_extent())
extent_crop = [2676546.0, 1246205.0, 2676596.0, 1246165.0]
# Out:
# BoundingBox(left=2676546.0, bottom=1246160.0, right=2676591.0, top=1246205.0)

# %%
out = "/home/wcherlet/repos/OccPy/data/cropped_out_test.tif"
data = model.crop2extent(extent_crop, out, res=0.1)

# %%
print(model.get_extent())
# Out:
# BoundingBox(left=2676546.0, bottom=1246165.0, right=2676591.0, top=1246205.0)
