# %% [markdown]
# # Test notebook to test lexcube voxel visualization

# %%
import lexcube
import numpy as np

# Load data
data = np.load(r"D:\_tmp_wdir\TestData_occpy\MLS\OcclusionMapping_OccPy_omp\Classification.npy")
# data cube needs to be rotated
data = np.rot90(data,2, [0, 1])
w = lexcube.Cube3DWidget(data, vmin=1, vmax=3)
w
# Out:
# Cube3DWidget(api_metadata={'/api': {'status': 'ok', 'api_version': 5}, '/api/datasets': [{'id': 'default', 'sh…
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File c:\Users\kueken\Miniconda3\envs\occPy\lib\site-packages\lexcube\lexcube_server\src\lexcube_widget.py:45, in start_tile_server_in_widget_mode.<locals>.receive_message(widget, content, buffers)
#      43 tile_server.pre_register_requests(requests)
#      44 for request in requests:
# ---> 45     response = tile_server.handle_tile_request_widget(request)
#      46     reply(response[0], response[1])
#
# File c:\Users\kueken\Miniconda3\envs\occPy\lib\site-packages\lexcube\lexcube_server\src\tile_server.py:1121, in TileServer.handle_tile_request_widget(self, request)
#    1119     d = self.tile_memory_cache.get_data(t)
#    1120 else:
# ...
